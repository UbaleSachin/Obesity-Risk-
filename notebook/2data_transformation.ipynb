# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\SACHIN\\PycharmProjects\\Obesity-Risk-\\notebook'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'c:\\Users\\SACHIN\\PycharmProjects\\Obesity-Risk-'

# %%
from dataclasses import dataclass
import os
from pathlib import Path

@dataclass(frozen= True)
class DataTransformationConfig:
    root : Path
    train_set : Path
    test_set: Path
    preprocessing_obj: Path

# %%
from src.ObesityRisk.constants import *
from src.ObesityRisk.utils.common import read_yaml, create_directories

# %%
class ConfigurationsManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_file])

    
    def get_transformation_config(self)-> DataTransformationConfig:
        config = self.config.data_transformation

        create_directories([config.root])
        create_directories([config.train_set])
        create_directories([config.test_set])
        #create_directories([config.preprocessing_obj])

        base_model_config = DataTransformationConfig(
            root = Path(config.root),
            train_set = Path(config.train_set),
            test_set = Path(config.test_set),
            preprocessing_obj = Path(config.preprocessing_obj)
        )

        return base_model_config

# %%
import os
import sys

import pandas as pd
import numpy as np
from pathlib import Path

from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

from ObesityRisk.utils.common import *
from ObesityRisk import logger
from ObesityRisk.constants import *

# %%
class PrepareTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    def data_split(self,
                csv_file_path = CSV_FILE_PATH,
                train_set_path = TRAIN_SET_PATH,
                test_set_path = TEST_SET_PATH,
                ):      
         
        self.csv = read_csv(csv_file_path)
        self.train = train_set_path
        self.test = test_set_path
        
        train_df, test_df = train_test_split(self.csv, test_size=0.2, random_state=42)

        train_df.to_csv(self.train)
        test_df.to_csv(self.test)
        logger.info(f'{train_df} and {test_df} split completed')

        return self.train, self.test


    def get_data_transformation_object(self,
                    csv_file_path = CSV_FILE_PATH):

        self.csv = read_csv(csv_file_path)
        numeric_features = self.csv.select_dtypes(include = [int, float]).columns.drop(['id'])
        categorical_features = self.csv.select_dtypes(include = object).columns.drop(['NObeyesdad'])


        numeric_pipeline = Pipeline(
            steps = [
                ('impiter', SimpleImputer(strategy = 'mean')),
                ('scaler', StandardScaler())
                ]
            )

        categorical_pipeline = Pipeline(
            steps = [
                ('imputer', SimpleImputer(strategy = 'most_frequent')),
                ('onehot', OneHotEncoder(handle_unknown = 'ignore')),
                ('scaler', StandardScaler(with_mean = False))
                ]
            )

        logger.info(f'numeric columns: {numeric_features} ')
        logger.info(f'categorical columns: {categorical_features} ')


        preprocessor = ColumnTransformer(
            [
                ('num_pipeline',numeric_pipeline, numeric_features),
                ('cat_pipeline',categorical_pipeline, categorical_features),
            ]
            )

        return preprocessor


    def initiate_data_transformation(self,
                                train_data, test_data, 
                                preprocessing_obj = PREPROCESSOR_PATH,
                                ):

        train_data = read_csv(TRAIN_SET_PATH)
        test_data = read_csv(TEST_SET_PATH)
        self.preprocessing_obj = preprocessing_obj

        logger.info(f"loading {train_data} and {test_data}")

        target_feature = ["NObeyesdad"]

        input_train_features = train_data.iloc[:,1:-1]
        target_input_train_feature = train_data['NObeyesdad']

        input_test_features = test_data.iloc[:,1:-1]
        traget_input_test_feture = test_data['NObeyesdad']

        logger.info(f'loading preprocessing object')

        preprocessing_obj = self.get_data_transformation_object()

        logger.info(f'applying preprocessing on {input_train_features} and {input_test_features}')

        input_train_array = preprocessing_obj.fit_transform(input_train_features)
        input_test_array = preprocessing_obj.transform(input_test_features)

        train_array = np.c_[input_train_array, np.array(target_input_train_feature)]
        test_array = np.c_[input_test_array, np.array(traget_input_test_feture)]

        logger.info("Saving the prerocessing objest")

        """save_pickle(path = self.preprocessing_obj,
        data = preprocessing_obj) """

        return train_array, test_array


config = ConfigurationsManager()
base_model_config = config.get_transformation_config()
data_transformation = PrepareTransformation(config=base_model_config)
train_data, test_data = data_transformation.data_split()
data_transformation.initiate_data_transformation(train_data, test_data)
# Out:
# [2024-03-01 13:49:27,601: INFO: common: yaml file Config\Config.yaml loaded successfully]
# [2024-03-01 13:49:27,606: INFO: common: yaml file params.yaml loaded successfully]
# [2024-03-01 13:49:27,610: INFO: common: creating directory at artifacts]
# [2024-03-01 13:49:27,612: INFO: common: creating directory at artifacts/data_transformation]
# [2024-03-01 13:49:27,614: INFO: common: creating directory at artifacts/data_transformation/train_set]
# [2024-03-01 13:49:27,617: INFO: common: creating directory at artifacts/data_transformation/test_set]
# [2024-03-01 13:49:28,347: INFO: 995533174:           id  Gender        Age    Height      Weight  \
# 9958    9958    Male  17.000000  1.770000   97.000000
# 7841    7841    Male  22.667596  1.753389   54.877111
# 9293    9293    Male  21.838323  1.819867  122.024954
# 15209  15209  Female  41.000000  1.580000   80.000000
# 16515  16515    Male  23.000000  1.800000   95.000000
# ...      ...     ...        ...       ...         ...
# 11284  11284  Female  18.000000  1.722461   80.442775
# 11964  11964    Male  22.000000  1.750000   95.000000
# 5390    5390    Male  21.000000  1.620000   68.000000
# 860      860  Female  26.000000  1.650125  111.939671
# 15795  15795    Male  37.997912  1.774330  107.998815
#
#       family_history_with_overweight FAVC      FCVC       NCP       CAEC  \
# 9958                             yes  yes  3.000000  3.000000     Always
# 7841                             yes  yes  2.000000  4.000000  Sometimes
# 9293                             yes  yes  3.000000  2.880817  Sometimes
# 15209                            yes  yes  2.000000  3.000000  Sometimes
# 16515                            yes   no  3.000000  3.000000  Sometimes
# ...                              ...  ...       ...       ...        ...
# 11284                            yes  yes  2.628791  2.562895  Sometimes
# 11964                            yes   no  3.000000  3.000000  Sometimes
# 5390                              no  yes  2.000000  3.000000     Always
# 860                              yes  yes  3.000000  3.000000  Sometimes
# 15795                            yes  yes  2.964419  2.902766  Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE        CALC  \
# 9958     no  2.000000  no  3.000000  1.000000          no
# 7841     no  2.000000  no  2.000000  1.000000          no
# 9293     no  1.645338  no  0.739881  0.000000   Sometimes
# 15209    no  1.000000  no  0.000000  0.000000   Sometimes
# 16515    no  3.000000  no  2.000000  1.000000  Frequently
# ...     ...       ...  ..       ...       ...         ...
# 11284    no  1.844645  no  0.288032  0.722276          no
# 11964    no  2.000000  no  3.000000  0.000000   Sometimes
# 5390     no  3.000000  no  2.000000  0.000000   Sometimes
# 860      no  2.770732  no  0.000000  0.237307   Sometimes
# 15795    no  2.745242  no  2.545707  0.000000   Sometimes
#
#                       MTRANS           NObeyesdad
# 9958              Automobile       Obesity_Type_I
# 7841   Public_Transportation  Insufficient_Weight
# 9293   Public_Transportation      Obesity_Type_II
# 15209             Automobile       Obesity_Type_I
# 16515  Public_Transportation  Overweight_Level_II
# ...                      ...                  ...
# 11284  Public_Transportation   Overweight_Level_I
# 11964  Public_Transportation  Overweight_Level_II
# 5390   Public_Transportation   Overweight_Level_I
# 860    Public_Transportation     Obesity_Type_III
# 15795             Automobile       Obesity_Type_I
#
# [16606 rows x 18 columns] and           id  Gender        Age    Height      Weight  \
# 10317  10317  Female  26.000000  1.649178  111.933010
# 4074    4074    Male  18.000000  1.750000   80.000000
# 9060    9060  Female  23.360307  1.713380   84.722222
# 11286  11286    Male  30.002029  1.670667  112.000381
# 8254    8254    Male  17.000000  1.610000   50.000000
# ...      ...     ...        ...       ...         ...
# 20286  20286  Female  16.000000  1.560000   51.000000
# 8233    8233    Male  18.000000  1.780000  108.000000
# 11518  11518  Female  22.693989  1.627908   82.000000
# 7947    7947    Male  33.185661  1.826970   87.000000
# 11274  11274    Male  21.024970  1.721854   80.000000
#
#       family_history_with_overweight FAVC      FCVC       NCP       CAEC  \
# 10317                            yes  yes  3.000000  3.000000  Sometimes
# 4074                              no  yes  2.000000  3.000000  Sometimes
# 9060                             yes  yes  2.880161  3.000000  Sometimes
# 11286                            yes  yes  1.572036  3.000000  Sometimes
# 8254                              no  yes  2.000000  3.000000  Sometimes
# ...                              ...  ...       ...       ...        ...
# 20286                             no  yes  2.000000  3.000000     Always
# 8233                             yes  yes  2.000000  1.000000  Sometimes
# 11518                            yes  yes  1.918251  1.000000  Sometimes
# 7947                             yes  yes  2.000000  1.000000  Sometimes
# 11274                            yes  yes  2.000000  1.630728  Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 10317    no  1.292479  no  0.065264  0.711331  Sometimes
# 4074     no  2.000000  no  1.000000  1.000000  Sometimes
# 9060     no  2.847264  no  2.000000  0.002600         no
# 11286    no  2.003563  no  0.000000  0.114457  Sometimes
# 8254     no  2.000000  no  0.000000  2.000000         no
# ...     ...       ...  ..       ...       ...        ...
# 20286    no  2.000000  no  1.000000  1.000000  Sometimes
# 8233     no  3.000000  no  1.000000  0.000000  Sometimes
# 11518    no  1.998108  no  0.000000  1.382906  Sometimes
# 7947     no  2.175632  no  2.000000  0.000000  Sometimes
# 11274    no  2.000000  no  1.000000  0.000000  Sometimes
#
#                       MTRANS           NObeyesdad
# 10317  Public_Transportation     Obesity_Type_III
# 4074   Public_Transportation   Overweight_Level_I
# 9060   Public_Transportation       Obesity_Type_I
# 11286  Public_Transportation      Obesity_Type_II
# 8254   Public_Transportation  Insufficient_Weight
# ...                      ...                  ...
# 20286  Public_Transportation        Normal_Weight
# 8233   Public_Transportation       Obesity_Type_I
# 11518  Public_Transportation       Obesity_Type_I
# 7947              Automobile   Overweight_Level_I
# 11274  Public_Transportation  Overweight_Level_II
#
# [4152 rows x 18 columns] split completed]
# [2024-03-01 13:49:28,542: INFO: 995533174: loading        Unnamed: 0     id  Gender        Age    Height      Weight  \
# 0            9958   9958    Male  17.000000  1.770000   97.000000
# 1            7841   7841    Male  22.667596  1.753389   54.877111
# 2            9293   9293    Male  21.838323  1.819867  122.024954
# 3           15209  15209  Female  41.000000  1.580000   80.000000
# 4           16515  16515    Male  23.000000  1.800000   95.000000
# ...           ...    ...     ...        ...       ...         ...
# 16601       11284  11284  Female  18.000000  1.722461   80.442775
# 16602       11964  11964    Male  22.000000  1.750000   95.000000
# 16603        5390   5390    Male  21.000000  1.620000   68.000000
# 16604         860    860  Female  26.000000  1.650125  111.939671
# 16605       15795  15795    Male  37.997912  1.774330  107.998815
#
#       family_history_with_overweight FAVC      FCVC       NCP       CAEC  \
# 0                                yes  yes  3.000000  3.000000     Always
# 1                                yes  yes  2.000000  4.000000  Sometimes
# 2                                yes  yes  3.000000  2.880817  Sometimes
# 3                                yes  yes  2.000000  3.000000  Sometimes
# 4                                yes   no  3.000000  3.000000  Sometimes
# ...                              ...  ...       ...       ...        ...
# 16601                            yes  yes  2.628791  2.562895  Sometimes
# 16602                            yes   no  3.000000  3.000000  Sometimes
# 16603                             no  yes  2.000000  3.000000     Always
# 16604                            yes  yes  3.000000  3.000000  Sometimes
# 16605                            yes  yes  2.964419  2.902766  Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE        CALC  \
# 0        no  2.000000  no  3.000000  1.000000          no
# 1        no  2.000000  no  2.000000  1.000000          no
# 2        no  1.645338  no  0.739881  0.000000   Sometimes
# 3        no  1.000000  no  0.000000  0.000000   Sometimes
# 4        no  3.000000  no  2.000000  1.000000  Frequently
# ...     ...       ...  ..       ...       ...         ...
# 16601    no  1.844645  no  0.288032  0.722276          no
# 16602    no  2.000000  no  3.000000  0.000000   Sometimes
# 16603    no  3.000000  no  2.000000  0.000000   Sometimes
# 16604    no  2.770732  no  0.000000  0.237307   Sometimes
# 16605    no  2.745242  no  2.545707  0.000000   Sometimes
#
#                       MTRANS           NObeyesdad
# 0                 Automobile       Obesity_Type_I
# 1      Public_Transportation  Insufficient_Weight
# 2      Public_Transportation      Obesity_Type_II
# 3                 Automobile       Obesity_Type_I
# 4      Public_Transportation  Overweight_Level_II
# ...                      ...                  ...
# 16601  Public_Transportation   Overweight_Level_I
# 16602  Public_Transportation  Overweight_Level_II
# 16603  Public_Transportation   Overweight_Level_I
# 16604  Public_Transportation     Obesity_Type_III
# 16605             Automobile       Obesity_Type_I
#
# [16606 rows x 19 columns] and       Unnamed: 0     id  Gender        Age    Height      Weight  \
# 0          10317  10317  Female  26.000000  1.649178  111.933010
# 1           4074   4074    Male  18.000000  1.750000   80.000000
# 2           9060   9060  Female  23.360307  1.713380   84.722222
# 3          11286  11286    Male  30.002029  1.670667  112.000381
# 4           8254   8254    Male  17.000000  1.610000   50.000000
# ...          ...    ...     ...        ...       ...         ...
# 4147       20286  20286  Female  16.000000  1.560000   51.000000
# 4148        8233   8233    Male  18.000000  1.780000  108.000000
# 4149       11518  11518  Female  22.693989  1.627908   82.000000
# 4150        7947   7947    Male  33.185661  1.826970   87.000000
# 4151       11274  11274    Male  21.024970  1.721854   80.000000
#
#      family_history_with_overweight FAVC      FCVC       NCP       CAEC SMOKE  \
# 0                               yes  yes  3.000000  3.000000  Sometimes    no
# 1                                no  yes  2.000000  3.000000  Sometimes    no
# 2                               yes  yes  2.880161  3.000000  Sometimes    no
# 3                               yes  yes  1.572036  3.000000  Sometimes    no
# 4                                no  yes  2.000000  3.000000  Sometimes    no
# ...                             ...  ...       ...       ...        ...   ...
# 4147                             no  yes  2.000000  3.000000     Always    no
# 4148                            yes  yes  2.000000  1.000000  Sometimes    no
# 4149                            yes  yes  1.918251  1.000000  Sometimes    no
# 4150                            yes  yes  2.000000  1.000000  Sometimes    no
# 4151                            yes  yes  2.000000  1.630728  Sometimes    no
#
#           CH2O SCC       FAF       TUE       CALC                 MTRANS  \
# 0     1.292479  no  0.065264  0.711331  Sometimes  Public_Transportation
# 1     2.000000  no  1.000000  1.000000  Sometimes  Public_Transportation
# 2     2.847264  no  2.000000  0.002600         no  Public_Transportation
# 3     2.003563  no  0.000000  0.114457  Sometimes  Public_Transportation
# 4     2.000000  no  0.000000  2.000000         no  Public_Transportation
# ...        ...  ..       ...       ...        ...                    ...
# 4147  2.000000  no  1.000000  1.000000  Sometimes  Public_Transportation
# 4148  3.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
# 4149  1.998108  no  0.000000  1.382906  Sometimes  Public_Transportation
# 4150  2.175632  no  2.000000  0.000000  Sometimes             Automobile
# 4151  2.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
#
#                NObeyesdad
# 0        Obesity_Type_III
# 1      Overweight_Level_I
# 2          Obesity_Type_I
# 3         Obesity_Type_II
# 4     Insufficient_Weight
# ...                   ...
# 4147        Normal_Weight
# 4148       Obesity_Type_I
# 4149       Obesity_Type_I
# 4150   Overweight_Level_I
# 4151  Overweight_Level_II
#
# [4152 rows x 19 columns]]
# [2024-03-01 13:49:28,557: INFO: 995533174: loading preprocessing object]
# [2024-03-01 13:49:28,671: INFO: 995533174: numeric columns: Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object') ]
# [2024-03-01 13:49:28,671: INFO: 995533174: categorical columns: Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS'],
#       dtype='object') ]
# [2024-03-01 13:49:28,719: INFO: 995533174: applying preprocessing on           id  Gender        Age    Height      Weight  \
# 0       9958    Male  17.000000  1.770000   97.000000
# 1       7841    Male  22.667596  1.753389   54.877111
# 2       9293    Male  21.838323  1.819867  122.024954
# 3      15209  Female  41.000000  1.580000   80.000000
# 4      16515    Male  23.000000  1.800000   95.000000
# ...      ...     ...        ...       ...         ...
# 16601  11284  Female  18.000000  1.722461   80.442775
# 16602  11964    Male  22.000000  1.750000   95.000000
# 16603   5390    Male  21.000000  1.620000   68.000000
# 16604    860  Female  26.000000  1.650125  111.939671
# 16605  15795    Male  37.997912  1.774330  107.998815
#
#       family_history_with_overweight FAVC      FCVC       NCP       CAEC  \
# 0                                yes  yes  3.000000  3.000000     Always
# 1                                yes  yes  2.000000  4.000000  Sometimes
# 2                                yes  yes  3.000000  2.880817  Sometimes
# 3                                yes  yes  2.000000  3.000000  Sometimes
# 4                                yes   no  3.000000  3.000000  Sometimes
# ...                              ...  ...       ...       ...        ...
# 16601                            yes  yes  2.628791  2.562895  Sometimes
# 16602                            yes   no  3.000000  3.000000  Sometimes
# 16603                             no  yes  2.000000  3.000000     Always
# 16604                            yes  yes  3.000000  3.000000  Sometimes
# 16605                            yes  yes  2.964419  2.902766  Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE        CALC  \
# 0        no  2.000000  no  3.000000  1.000000          no
# 1        no  2.000000  no  2.000000  1.000000          no
# 2        no  1.645338  no  0.739881  0.000000   Sometimes
# 3        no  1.000000  no  0.000000  0.000000   Sometimes
# 4        no  3.000000  no  2.000000  1.000000  Frequently
# ...     ...       ...  ..       ...       ...         ...
# 16601    no  1.844645  no  0.288032  0.722276          no
# 16602    no  2.000000  no  3.000000  0.000000   Sometimes
# 16603    no  3.000000  no  2.000000  0.000000   Sometimes
# 16604    no  2.770732  no  0.000000  0.237307   Sometimes
# 16605    no  2.745242  no  2.545707  0.000000   Sometimes
#
#                       MTRANS
# 0                 Automobile
# 1      Public_Transportation
# 2      Public_Transportation
# 3                 Automobile
# 4      Public_Transportation
# ...                      ...
# 16601  Public_Transportation
# 16602  Public_Transportation
# 16603  Public_Transportation
# 16604  Public_Transportation
# 16605             Automobile
#
# [16606 rows x 17 columns] and          id  Gender        Age    Height      Weight  \
# 0     10317  Female  26.000000  1.649178  111.933010
# 1      4074    Male  18.000000  1.750000   80.000000
# 2      9060  Female  23.360307  1.713380   84.722222
# 3     11286    Male  30.002029  1.670667  112.000381
# 4      8254    Male  17.000000  1.610000   50.000000
# ...     ...     ...        ...       ...         ...
# 4147  20286  Female  16.000000  1.560000   51.000000
# 4148   8233    Male  18.000000  1.780000  108.000000
# 4149  11518  Female  22.693989  1.627908   82.000000
# 4150   7947    Male  33.185661  1.826970   87.000000
# 4151  11274    Male  21.024970  1.721854   80.000000
#
#      family_history_with_overweight FAVC      FCVC       NCP       CAEC SMOKE  \
# 0                               yes  yes  3.000000  3.000000  Sometimes    no
# 1                                no  yes  2.000000  3.000000  Sometimes    no
# 2                               yes  yes  2.880161  3.000000  Sometimes    no
# 3                               yes  yes  1.572036  3.000000  Sometimes    no
# 4                                no  yes  2.000000  3.000000  Sometimes    no
# ...                             ...  ...       ...       ...        ...   ...
# 4147                             no  yes  2.000000  3.000000     Always    no
# 4148                            yes  yes  2.000000  1.000000  Sometimes    no
# 4149                            yes  yes  1.918251  1.000000  Sometimes    no
# 4150                            yes  yes  2.000000  1.000000  Sometimes    no
# 4151                            yes  yes  2.000000  1.630728  Sometimes    no
#
#           CH2O SCC       FAF       TUE       CALC                 MTRANS
# 0     1.292479  no  0.065264  0.711331  Sometimes  Public_Transportation
# 1     2.000000  no  1.000000  1.000000  Sometimes  Public_Transportation
# 2     2.847264  no  2.000000  0.002600         no  Public_Transportation
# 3     2.003563  no  0.000000  0.114457  Sometimes  Public_Transportation
# 4     2.000000  no  0.000000  2.000000         no  Public_Transportation
# ...        ...  ..       ...       ...        ...                    ...
# 4147  2.000000  no  1.000000  1.000000  Sometimes  Public_Transportation
# 4148  3.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
# 4149  1.998108  no  0.000000  1.382906  Sometimes  Public_Transportation
# 4150  2.175632  no  2.000000  0.000000  Sometimes             Automobile
# 4151  2.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
#
# [4152 rows x 17 columns]]
# [2024-03-01 13:49:28,967: INFO: 995533174: Saving the prerocessing objest]
# (array([[-1.19937194293628, 0.8008164212166569, 0.34352742257698393, ...,
#          0.0, 0.0, 'Obesity_Type_I'],
#         [-0.21319639748705266, 0.6102426172010293, -1.2566015711622052,
#          ..., 2.512337998171704, 0.0, 'Insufficient_Weight'],
#         [-0.3574919247443444, 1.3729279066689062, 1.2941543955367325, ...,
#          2.512337998171704, 0.0, 'Obesity_Type_II'],
#         ...,
#         [-0.5033621741036197, -0.9200956612795341, -0.7581002653633301,
#          ..., 2.512337998171704, 0.0, 'Overweight_Level_I'],
#         [0.36665003693720544, -0.5744791513782161, 0.9110431198983275,
#          ..., 2.512337998171704, 0.0, 'Obesity_Type_III'],
#         [2.454316026335855, 0.850493416664713, 0.7613411859746818, ...,
#          0.0, 0.0, 'Obesity_Type_I']], dtype=object),
#  array([[0.36665003693720544, -0.5853438429923757, 0.9107900874145558,
#          ..., 2.512337998171704, 0.0, 'Obesity_Type_III'],
#         [-1.025369500728115, 0.571361476883831, -0.3022543255259587, ...,
#          2.512337998171704, 0.0, 'Overweight_Level_I'],
#         [-0.09266299174259258, 0.15122947381042623, -0.12287051505006606,
#          ..., 2.512337998171704, 0.0, 'Obesity_Type_I'],
#         ...,
#         [-0.20860395102985277, -0.8293691762903371, -0.2262800022197302,
#          ..., 2.512337998171704, 0.0, 'Obesity_Type_I'],
#         [1.6169725998171713, 1.4544188301487102, -0.03634419395415881,
#          ..., 0.0, 0.0, 'Overweight_Level_I'],
#         [-0.49901733312168195, 0.24844953372424552, -0.3022543255259587,
#          ..., 2.512337998171704, 0.0, 'Overweight_Level_II']], dtype=object))

# %%
try:
    config = ConfigurationsManager()
    base_model_config = config.get_transformation_config()
    data_transformation = PrepareTransformation(config=base_model_config)
    train_data, test_data = data_transformation.data_split()
    data_transformation.initiate_data_transformation(train_data, test_data)
except Exception as e:
    raise e
# Out:
# [2024-02-29 21:24:02,773: INFO: common: yaml file Config\Config.yaml loaded successfully]
# [2024-02-29 21:24:02,780: INFO: common: yaml file params.yaml loaded successfully]
# [2024-02-29 21:24:02,782: INFO: common: creating directory at artifacts]
# [2024-02-29 21:24:02,786: INFO: common: creating directory at artifacts/data_transformation]
# [2024-02-29 21:24:02,787: INFO: common: creating directory at artifacts/data_transformation/train_set]
# [2024-02-29 21:24:02,790: INFO: common: creating directory at artifacts/data_transformation/test_set]
# [2024-02-29 21:24:03,470: INFO: 1504628871:           id  Gender        Age    Height      Weight  \
# 9958    9958    Male  17.000000  1.770000   97.000000
# 7841    7841    Male  22.667596  1.753389   54.877111
# 9293    9293    Male  21.838323  1.819867  122.024954
# 15209  15209  Female  41.000000  1.580000   80.000000
# 16515  16515    Male  23.000000  1.800000   95.000000
# ...      ...     ...        ...       ...         ...
# 11284  11284  Female  18.000000  1.722461   80.442775
# 11964  11964    Male  22.000000  1.750000   95.000000
# 5390    5390    Male  21.000000  1.620000   68.000000
# 860      860  Female  26.000000  1.650125  111.939671
# 15795  15795    Male  37.997912  1.774330  107.998815
#
#       family_history_with_overweight FAVC      FCVC       NCP       CAEC  \
# 9958                             yes  yes  3.000000  3.000000     Always
# 7841                             yes  yes  2.000000  4.000000  Sometimes
# 9293                             yes  yes  3.000000  2.880817  Sometimes
# 15209                            yes  yes  2.000000  3.000000  Sometimes
# 16515                            yes   no  3.000000  3.000000  Sometimes
# ...                              ...  ...       ...       ...        ...
# 11284                            yes  yes  2.628791  2.562895  Sometimes
# 11964                            yes   no  3.000000  3.000000  Sometimes
# 5390                              no  yes  2.000000  3.000000     Always
# 860                              yes  yes  3.000000  3.000000  Sometimes
# 15795                            yes  yes  2.964419  2.902766  Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE        CALC  \
# 9958     no  2.000000  no  3.000000  1.000000          no
# 7841     no  2.000000  no  2.000000  1.000000          no
# 9293     no  1.645338  no  0.739881  0.000000   Sometimes
# 15209    no  1.000000  no  0.000000  0.000000   Sometimes
# 16515    no  3.000000  no  2.000000  1.000000  Frequently
# ...     ...       ...  ..       ...       ...         ...
# 11284    no  1.844645  no  0.288032  0.722276          no
# 11964    no  2.000000  no  3.000000  0.000000   Sometimes
# 5390     no  3.000000  no  2.000000  0.000000   Sometimes
# 860      no  2.770732  no  0.000000  0.237307   Sometimes
# 15795    no  2.745242  no  2.545707  0.000000   Sometimes
#
#                       MTRANS           NObeyesdad
# 9958              Automobile       Obesity_Type_I
# 7841   Public_Transportation  Insufficient_Weight
# 9293   Public_Transportation      Obesity_Type_II
# 15209             Automobile       Obesity_Type_I
# 16515  Public_Transportation  Overweight_Level_II
# ...                      ...                  ...
# 11284  Public_Transportation   Overweight_Level_I
# 11964  Public_Transportation  Overweight_Level_II
# 5390   Public_Transportation   Overweight_Level_I
# 860    Public_Transportation     Obesity_Type_III
# 15795             Automobile       Obesity_Type_I
#
# [16606 rows x 18 columns] and           id  Gender        Age    Height      Weight  \
# 10317  10317  Female  26.000000  1.649178  111.933010
# 4074    4074    Male  18.000000  1.750000   80.000000
# 9060    9060  Female  23.360307  1.713380   84.722222
# 11286  11286    Male  30.002029  1.670667  112.000381
# 8254    8254    Male  17.000000  1.610000   50.000000
# ...      ...     ...        ...       ...         ...
# 20286  20286  Female  16.000000  1.560000   51.000000
# 8233    8233    Male  18.000000  1.780000  108.000000
# 11518  11518  Female  22.693989  1.627908   82.000000
# 7947    7947    Male  33.185661  1.826970   87.000000
# 11274  11274    Male  21.024970  1.721854   80.000000
#
#       family_history_with_overweight FAVC      FCVC       NCP       CAEC  \
# 10317                            yes  yes  3.000000  3.000000  Sometimes
# 4074                              no  yes  2.000000  3.000000  Sometimes
# 9060                             yes  yes  2.880161  3.000000  Sometimes
# 11286                            yes  yes  1.572036  3.000000  Sometimes
# 8254                              no  yes  2.000000  3.000000  Sometimes
# ...                              ...  ...       ...       ...        ...
# 20286                             no  yes  2.000000  3.000000     Always
# 8233                             yes  yes  2.000000  1.000000  Sometimes
# 11518                            yes  yes  1.918251  1.000000  Sometimes
# 7947                             yes  yes  2.000000  1.000000  Sometimes
# 11274                            yes  yes  2.000000  1.630728  Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 10317    no  1.292479  no  0.065264  0.711331  Sometimes
# 4074     no  2.000000  no  1.000000  1.000000  Sometimes
# 9060     no  2.847264  no  2.000000  0.002600         no
# 11286    no  2.003563  no  0.000000  0.114457  Sometimes
# 8254     no  2.000000  no  0.000000  2.000000         no
# ...     ...       ...  ..       ...       ...        ...
# 20286    no  2.000000  no  1.000000  1.000000  Sometimes
# 8233     no  3.000000  no  1.000000  0.000000  Sometimes
# 11518    no  1.998108  no  0.000000  1.382906  Sometimes
# 7947     no  2.175632  no  2.000000  0.000000  Sometimes
# 11274    no  2.000000  no  1.000000  0.000000  Sometimes
#
#                       MTRANS           NObeyesdad
# 10317  Public_Transportation     Obesity_Type_III
# 4074   Public_Transportation   Overweight_Level_I
# 9060   Public_Transportation       Obesity_Type_I
# 11286  Public_Transportation      Obesity_Type_II
# 8254   Public_Transportation  Insufficient_Weight
# ...                      ...                  ...
# 20286  Public_Transportation        Normal_Weight
# 8233   Public_Transportation       Obesity_Type_I
# 11518  Public_Transportation       Obesity_Type_I
# 7947              Automobile   Overweight_Level_I
# 11274  Public_Transportation  Overweight_Level_II
#
# [4152 rows x 18 columns] split completed]
# [2024-02-29 21:24:03,671: INFO: 1504628871: loading        Unnamed: 0     id  Gender        Age    Height      Weight  \
# 0            9958   9958    Male  17.000000  1.770000   97.000000
# 1            7841   7841    Male  22.667596  1.753389   54.877111
# 2            9293   9293    Male  21.838323  1.819867  122.024954
# 3           15209  15209  Female  41.000000  1.580000   80.000000
# 4           16515  16515    Male  23.000000  1.800000   95.000000
# ...           ...    ...     ...        ...       ...         ...
# 16601       11284  11284  Female  18.000000  1.722461   80.442775
# 16602       11964  11964    Male  22.000000  1.750000   95.000000
# 16603        5390   5390    Male  21.000000  1.620000   68.000000
# 16604         860    860  Female  26.000000  1.650125  111.939671
# 16605       15795  15795    Male  37.997912  1.774330  107.998815
#
#       family_history_with_overweight FAVC      FCVC       NCP       CAEC  \
# 0                                yes  yes  3.000000  3.000000     Always
# 1                                yes  yes  2.000000  4.000000  Sometimes
# 2                                yes  yes  3.000000  2.880817  Sometimes
# 3                                yes  yes  2.000000  3.000000  Sometimes
# 4                                yes   no  3.000000  3.000000  Sometimes
# ...                              ...  ...       ...       ...        ...
# 16601                            yes  yes  2.628791  2.562895  Sometimes
# 16602                            yes   no  3.000000  3.000000  Sometimes
# 16603                             no  yes  2.000000  3.000000     Always
# 16604                            yes  yes  3.000000  3.000000  Sometimes
# 16605                            yes  yes  2.964419  2.902766  Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE        CALC  \
# 0        no  2.000000  no  3.000000  1.000000          no
# 1        no  2.000000  no  2.000000  1.000000          no
# 2        no  1.645338  no  0.739881  0.000000   Sometimes
# 3        no  1.000000  no  0.000000  0.000000   Sometimes
# 4        no  3.000000  no  2.000000  1.000000  Frequently
# ...     ...       ...  ..       ...       ...         ...
# 16601    no  1.844645  no  0.288032  0.722276          no
# 16602    no  2.000000  no  3.000000  0.000000   Sometimes
# 16603    no  3.000000  no  2.000000  0.000000   Sometimes
# 16604    no  2.770732  no  0.000000  0.237307   Sometimes
# 16605    no  2.745242  no  2.545707  0.000000   Sometimes
#
#                       MTRANS           NObeyesdad
# 0                 Automobile       Obesity_Type_I
# 1      Public_Transportation  Insufficient_Weight
# 2      Public_Transportation      Obesity_Type_II
# 3                 Automobile       Obesity_Type_I
# 4      Public_Transportation  Overweight_Level_II
# ...                      ...                  ...
# 16601  Public_Transportation   Overweight_Level_I
# 16602  Public_Transportation  Overweight_Level_II
# 16603  Public_Transportation   Overweight_Level_I
# 16604  Public_Transportation     Obesity_Type_III
# 16605             Automobile       Obesity_Type_I
#
# [16606 rows x 19 columns] and       Unnamed: 0     id  Gender        Age    Height      Weight  \
# 0          10317  10317  Female  26.000000  1.649178  111.933010
# 1           4074   4074    Male  18.000000  1.750000   80.000000
# 2           9060   9060  Female  23.360307  1.713380   84.722222
# 3          11286  11286    Male  30.002029  1.670667  112.000381
# 4           8254   8254    Male  17.000000  1.610000   50.000000
# ...          ...    ...     ...        ...       ...         ...
# 4147       20286  20286  Female  16.000000  1.560000   51.000000
# 4148        8233   8233    Male  18.000000  1.780000  108.000000
# 4149       11518  11518  Female  22.693989  1.627908   82.000000
# 4150        7947   7947    Male  33.185661  1.826970   87.000000
# 4151       11274  11274    Male  21.024970  1.721854   80.000000
#
#      family_history_with_overweight FAVC      FCVC       NCP       CAEC SMOKE  \
# 0                               yes  yes  3.000000  3.000000  Sometimes    no
# 1                                no  yes  2.000000  3.000000  Sometimes    no
# 2                               yes  yes  2.880161  3.000000  Sometimes    no
# 3                               yes  yes  1.572036  3.000000  Sometimes    no
# 4                                no  yes  2.000000  3.000000  Sometimes    no
# ...                             ...  ...       ...       ...        ...   ...
# 4147                             no  yes  2.000000  3.000000     Always    no
# 4148                            yes  yes  2.000000  1.000000  Sometimes    no
# 4149                            yes  yes  1.918251  1.000000  Sometimes    no
# 4150                            yes  yes  2.000000  1.000000  Sometimes    no
# 4151                            yes  yes  2.000000  1.630728  Sometimes    no
#
#           CH2O SCC       FAF       TUE       CALC                 MTRANS  \
# 0     1.292479  no  0.065264  0.711331  Sometimes  Public_Transportation
# 1     2.000000  no  1.000000  1.000000  Sometimes  Public_Transportation
# 2     2.847264  no  2.000000  0.002600         no  Public_Transportation
# 3     2.003563  no  0.000000  0.114457  Sometimes  Public_Transportation
# 4     2.000000  no  0.000000  2.000000         no  Public_Transportation
# ...        ...  ..       ...       ...        ...                    ...
# 4147  2.000000  no  1.000000  1.000000  Sometimes  Public_Transportation
# 4148  3.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
# 4149  1.998108  no  0.000000  1.382906  Sometimes  Public_Transportation
# 4150  2.175632  no  2.000000  0.000000  Sometimes             Automobile
# 4151  2.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
#
#                NObeyesdad
# 0        Obesity_Type_III
# 1      Overweight_Level_I
# 2          Obesity_Type_I
# 3         Obesity_Type_II
# 4     Insufficient_Weight
# ...                   ...
# 4147        Normal_Weight
# 4148       Obesity_Type_I
# 4149       Obesity_Type_I
# 4150   Overweight_Level_I
# 4151  Overweight_Level_II
#
# [4152 rows x 19 columns]]
# [2024-02-29 21:24:03,681: INFO: 1504628871: loading preprocessing object]
# [2024-02-29 21:24:03,800: INFO: 1504628871: numeric columns: Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object') ]
# [2024-02-29 21:24:03,801: INFO: 1504628871: categorical columns: Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS'],
#       dtype='object') ]
# [2024-02-29 21:24:03,832: INFO: 1504628871: applying preprocessing on           id  Gender        Age    Height      Weight  \
# 0       9958    Male  17.000000  1.770000   97.000000
# 1       7841    Male  22.667596  1.753389   54.877111
# 2       9293    Male  21.838323  1.819867  122.024954
# 3      15209  Female  41.000000  1.580000   80.000000
# 4      16515    Male  23.000000  1.800000   95.000000
# ...      ...     ...        ...       ...         ...
# 16601  11284  Female  18.000000  1.722461   80.442775
# 16602  11964    Male  22.000000  1.750000   95.000000
# 16603   5390    Male  21.000000  1.620000   68.000000
# 16604    860  Female  26.000000  1.650125  111.939671
# 16605  15795    Male  37.997912  1.774330  107.998815
#
#       family_history_with_overweight FAVC      FCVC       NCP       CAEC  \
# 0                                yes  yes  3.000000  3.000000     Always
# 1                                yes  yes  2.000000  4.000000  Sometimes
# 2                                yes  yes  3.000000  2.880817  Sometimes
# 3                                yes  yes  2.000000  3.000000  Sometimes
# 4                                yes   no  3.000000  3.000000  Sometimes
# ...                              ...  ...       ...       ...        ...
# 16601                            yes  yes  2.628791  2.562895  Sometimes
# 16602                            yes   no  3.000000  3.000000  Sometimes
# 16603                             no  yes  2.000000  3.000000     Always
# 16604                            yes  yes  3.000000  3.000000  Sometimes
# 16605                            yes  yes  2.964419  2.902766  Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE        CALC  \
# 0        no  2.000000  no  3.000000  1.000000          no
# 1        no  2.000000  no  2.000000  1.000000          no
# 2        no  1.645338  no  0.739881  0.000000   Sometimes
# 3        no  1.000000  no  0.000000  0.000000   Sometimes
# 4        no  3.000000  no  2.000000  1.000000  Frequently
# ...     ...       ...  ..       ...       ...         ...
# 16601    no  1.844645  no  0.288032  0.722276          no
# 16602    no  2.000000  no  3.000000  0.000000   Sometimes
# 16603    no  3.000000  no  2.000000  0.000000   Sometimes
# 16604    no  2.770732  no  0.000000  0.237307   Sometimes
# 16605    no  2.745242  no  2.545707  0.000000   Sometimes
#
#                       MTRANS
# 0                 Automobile
# 1      Public_Transportation
# 2      Public_Transportation
# 3                 Automobile
# 4      Public_Transportation
# ...                      ...
# 16601  Public_Transportation
# 16602  Public_Transportation
# 16603  Public_Transportation
# 16604  Public_Transportation
# 16605             Automobile
#
# [16606 rows x 17 columns] and          id  Gender        Age    Height      Weight  \
# 0     10317  Female  26.000000  1.649178  111.933010
# 1      4074    Male  18.000000  1.750000   80.000000
# 2      9060  Female  23.360307  1.713380   84.722222
# 3     11286    Male  30.002029  1.670667  112.000381
# 4      8254    Male  17.000000  1.610000   50.000000
# ...     ...     ...        ...       ...         ...
# 4147  20286  Female  16.000000  1.560000   51.000000
# 4148   8233    Male  18.000000  1.780000  108.000000
# 4149  11518  Female  22.693989  1.627908   82.000000
# 4150   7947    Male  33.185661  1.826970   87.000000
# 4151  11274    Male  21.024970  1.721854   80.000000
#
#      family_history_with_overweight FAVC      FCVC       NCP       CAEC SMOKE  \
# 0                               yes  yes  3.000000  3.000000  Sometimes    no
# 1                                no  yes  2.000000  3.000000  Sometimes    no
# 2                               yes  yes  2.880161  3.000000  Sometimes    no
# 3                               yes  yes  1.572036  3.000000  Sometimes    no
# 4                                no  yes  2.000000  3.000000  Sometimes    no
# ...                             ...  ...       ...       ...        ...   ...
# 4147                             no  yes  2.000000  3.000000     Always    no
# 4148                            yes  yes  2.000000  1.000000  Sometimes    no
# 4149                            yes  yes  1.918251  1.000000  Sometimes    no
# 4150                            yes  yes  2.000000  1.000000  Sometimes    no
# 4151                            yes  yes  2.000000  1.630728  Sometimes    no
#
#           CH2O SCC       FAF       TUE       CALC                 MTRANS
# 0     1.292479  no  0.065264  0.711331  Sometimes  Public_Transportation
# 1     2.000000  no  1.000000  1.000000  Sometimes  Public_Transportation
# 2     2.847264  no  2.000000  0.002600         no  Public_Transportation
# 3     2.003563  no  0.000000  0.114457  Sometimes  Public_Transportation
# 4     2.000000  no  0.000000  2.000000         no  Public_Transportation
# ...        ...  ..       ...       ...        ...                    ...
# 4147  2.000000  no  1.000000  1.000000  Sometimes  Public_Transportation
# 4148  3.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
# 4149  1.998108  no  0.000000  1.382906  Sometimes  Public_Transportation
# 4150  2.175632  no  2.000000  0.000000  Sometimes             Automobile
# 4151  2.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
#
# [4152 rows x 17 columns]]
# [2024-02-29 21:24:04,061: INFO: 1504628871: Saving the prerocessing objest]
